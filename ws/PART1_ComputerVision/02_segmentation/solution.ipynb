# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -U ultralytics
# !pip install opencv-python-headless
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 33.9 MB/s eta 0:00:00
# ...

# %%
# !yolo segment train project='/content/drive/MyDrive/shinfang/ws/PART1_ComputerVision/02_segmentation/runs/segment/' data='/content/drive/MyDrive/shinfang/ws/PART1_ComputerVision/02_segmentation/train/coco_dataset/data.yaml' model=yolov8n-seg.pt epochs=100 imgsz=320
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.214 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo segment predict project='/content/drive/MyDrive/shinfang/ws/PART1_ComputerVision/02_segmentation/runs/segment/' model='/content/drive/MyDrive/shinfang/ws/PART1_ComputerVision/02_segmentation/runs/segment/train/weights/best.pt' source='/content/drive/MyDrive/shinfang/ws/PART1_ComputerVision/02_segmentation/test' save=True
# Out:
# Ultralytics 8.3.214 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n-seg summary (fused): 85 layers, 3,258,844 parameters, 0 gradients, 11.3 GFLOPs
#
# image 1/4357 /content/drive/MyDrive/shinfang/ws/PART1_ComputerVision/02_segmentation/test/00000_rgb.png: 320x320 1 pot, 1 bowl, 1 spatula, 1 egg, 6.8ms
# image 2/4357 /content/drive/MyDrive/shinfang/ws/PART1_ComputerVision/02_segmentation/test/00001_rgb.png: 320x320 1 pot, 1 bowl, 1 spatula, 1 egg, 6.9ms
# image 3/4357 /content/drive/MyDrive/shinfang/ws/PART1_ComputerVision/02_segmentation/test/00002_rgb.png: 320x320 1 pot, 1 bowl, 1 spatula, 1 egg, 6.6ms
# image 4/4357 /content/drive/MyDrive/shinfang/ws/PART1_ComputerVision/02_segmentation/test/00003_rgb.png: 320x320 1 pot, 1 bowl, 1 spatula, 1 egg, 6.7ms
# image 5/4357 /content/drive/MyDrive/shinfang/ws/PART1_ComputerVision/02_segmentation/test/00004_rgb.png: 320x320 1 pot, 1 bowl, 1 spatula, 1 egg, 6.8ms
# ...
